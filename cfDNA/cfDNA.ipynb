# %%
# %run cfDNA.py \
    --modalities Frag CNV PFE NDR NDR2K \
    --data_file ../database/cfDNA/cancer_and_benign/train.npz \
    --test_file ../database/cfDNA/cancer_and_benign/test.npz \
    --epochs 100
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.3636
# New best model saved at epoch 7 with Val F1: 0.6500
# Epoch 50: Train Acc=96.4%, Val Acc=57.1%, F1=0.5333, AUC=0.6667
# New best model saved at epoch 51 with Val F1: 0.7083
# Epoch 100: Train Acc=100.0%, Val Acc=57.1%, F1=0.5714, AUC=0.6667
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 0.3636
# New best model saved at epoch 5 with Val F1: 0.6500
# New best model saved at epoch 29 with Val F1: 0.7083
# Epoch 50: Train Acc=94.6%, Val Acc=71.4%, F1=0.7083, AUC=0.8333
# New best model saved at epoch 57 with Val F1: 0.8571
# Epoch 100: Train Acc=100.0%, Val Acc=57.1%, F1=0.5333, AUC=0.7500
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.3000
# New best model saved at epoch 4 with Val F1: 0.5333
# New best model saved at epoch 6 with Val F1: 0.7083
# Epoch 50: Train Acc=96.4%, Val Acc=42.9%, F1=0.4167, AUC=0.5833
# Epoch 100: Train Acc=98.2%, Val Acc=57.1%, F1=0.5333, AUC=0.7500
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.2500
# New best model saved at epoch 8 with Val F1: 0.3333
# New best model saved at epoch 10 with Val F1: 0.4857
# Epoch 50: Train Acc=94.7%, Val Acc=33.3%, F1=0.3333, AUC=0.3750
# Epoch 100: Train Acc=98.2%, Val Acc=33.3%, F1=0.3333, AUC=0.3750
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.2500
# New best model saved at epoch 3 with Val F1: 0.4857
# New best model saved at epoch 4 with Val F1: 0.6667
# Epoch 50: Train Acc=96.5%, Val Acc=50.0%, F1=0.4857, AUC=0.6250
# New best model saved at epoch 62 with Val F1: 0.8286
# Epoch 100: Train Acc=98.2%, Val Acc=66.7%, F1=0.6667, AUC=0.7500
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.4000
# New best model saved at epoch 21 with Val F1: 0.7778
# Epoch 50: Train Acc=96.5%, Val Acc=66.7%, F1=0.6667, AUC=0.7500
# Epoch 100: Train Acc=98.2%, Val Acc=66.7%, F1=0.6667, AUC=0.5000
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.3333
# Epoch 50: Train Acc=89.5%, Val Acc=50.0%, F1=0.3333, AUC=1.0000
# New best model saved at epoch 70 with Val F1: 0.6250
# Epoch 100: Train Acc=98.2%, Val Acc=66.7%, F1=0.6250, AUC=0.8889
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.3333
# New best model saved at epoch 4 with Val F1: 0.4857
# New best model saved at epoch 32 with Val F1: 0.6250
# Epoch 50: Train Acc=94.7%, Val Acc=66.7%, F1=0.6250, AUC=0.6667
# Epoch 100: Train Acc=98.2%, Val Acc=50.0%, F1=0.4857, AUC=0.7778
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.3333
# New best model saved at epoch 23 with Val F1: 0.4857
# Epoch 50: Train Acc=93.0%, Val Acc=50.0%, F1=0.4857, AUC=0.6667
# Epoch 100: Train Acc=100.0%, Val Acc=50.0%, F1=0.4857, AUC=0.6667
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.3333
# New best model saved at epoch 15 with Val F1: 0.4857
# New best model saved at epoch 30 with Val F1: 0.6667
# New best model saved at epoch 46 with Val F1: 0.8286
# Epoch 50: Train Acc=94.7%, Val Acc=83.3%, F1=0.8286, AUC=0.6667
# Epoch 100: Train Acc=100.0%, Val Acc=83.3%, F1=0.8286, AUC=0.6667
#
# Average F1: 0.6930 ± 0.1291
# Average AUC: 0.7028 ± 0.1570
#
# Evaluating on independent test set...
#
# Test Set Results:
# Fold 1: Acc=28.6%, F1=0.2222, AUC=0.1667
# Fold 2: Acc=28.6%, F1=0.2222, AUC=0.1667
# Fold 3: Acc=42.9%, F1=0.3000, AUC=0.1667
# Fold 4: Acc=28.6%, F1=0.2222, AUC=0.2500
# Fold 5: Acc=42.9%, F1=0.4167, AUC=0.1667
# Fold 6: Acc=42.9%, F1=0.4167, AUC=0.1667
# Fold 7: Acc=42.9%, F1=0.4167, AUC=0.1667
# Fold 8: Acc=42.9%, F1=0.4167, AUC=0.2500
# Fold 9: Acc=42.9%, F1=0.4167, AUC=0.1667
# Fold 10: Acc=42.9%, F1=0.4167, AUC=0.2500
#
# Average Test F1: 0.3467
# Average Test AUC: 0.1917

# %%
# %run cfDNA.py \
    --modalities CNV \
    --data_file ../database/cfDNA/train.npz \
    --test_file ../database/cfDNA/test.npz \
    --epochs 20
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.9206
# New best model saved at epoch 5 with Val F1: 1.0000
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 1.0000
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.8172
# New best model saved at epoch 2 with Val F1: 0.9204
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.4688
# New best model saved at epoch 2 with Val F1: 0.8172
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.3321
# New best model saved at epoch 2 with Val F1: 0.6964
# New best model saved at epoch 3 with Val F1: 0.8079
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.6762
# New best model saved at epoch 2 with Val F1: 0.9204
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.8172
# New best model saved at epoch 2 with Val F1: 0.8921
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.8583
# New best model saved at epoch 2 with Val F1: 0.9204
# New best model saved at epoch 14 with Val F1: 1.0000
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.7344
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.6151
# New best model saved at epoch 2 with Val F1: 0.6344
# New best model saved at epoch 4 with Val F1: 0.6762
# New best model saved at epoch 13 with Val F1: 0.7344
#
# Average F1: 0.8827 ± 0.0990
# Average AUC: 0.9041 ± 0.1029
#
# Evaluating on independent test set...
#
# Test Set Results:
# Fold 1: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 2: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 3: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 4: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 5: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 6: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 7: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 8: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 9: Acc=100.0%, F1=1.0000, AUC=1.0000
# Fold 10: Acc=100.0%, F1=1.0000, AUC=1.0000
#
# Average Test F1: 1.0000
# Average Test AUC: 1.0000

# %%
# %run finetune_noct.py \
    --modalities Frag \
    --data_file ../database/cfDNA/train/multimodal_data.npz \
    --epochs 100
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.4306
# Epoch 50: Train Acc=76.1%, Val Acc=75.6%, F1=0.4306, AUC=0.4935
# New best model saved at epoch 88 with Val F1: 0.5275
# Epoch 100: Train Acc=78.0%, Val Acc=78.0%, F1=0.5275, AUC=0.5032
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 0.4306
# Epoch 50: Train Acc=75.5%, Val Acc=75.6%, F1=0.4306, AUC=0.5677
# Epoch 100: Train Acc=76.1%, Val Acc=75.6%, F1=0.4306, AUC=0.5806
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.4306
# Epoch 50: Train Acc=75.8%, Val Acc=75.6%, F1=0.4306, AUC=0.7323
# Epoch 100: Train Acc=76.6%, Val Acc=75.6%, F1=0.4306, AUC=0.7355
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.4306
# Epoch 50: Train Acc=75.5%, Val Acc=75.6%, F1=0.4306, AUC=0.5226
# Epoch 100: Train Acc=75.8%, Val Acc=75.6%, F1=0.4306, AUC=0.5516
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.4306
# Epoch 50: Train Acc=75.5%, Val Acc=75.6%, F1=0.4306, AUC=0.8065
# Epoch 100: Train Acc=76.6%, Val Acc=75.6%, F1=0.4306, AUC=0.8032
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.4531
# Epoch 50: Train Acc=75.3%, Val Acc=77.5%, F1=0.4366, AUC=0.5269
# Epoch 100: Train Acc=75.6%, Val Acc=77.5%, F1=0.4366, AUC=0.5018
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.6154
# Epoch 50: Train Acc=75.6%, Val Acc=75.0%, F1=0.4286, AUC=0.6767
# Epoch 100: Train Acc=76.4%, Val Acc=75.0%, F1=0.4286, AUC=0.6767
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.5943
# New best model saved at epoch 2 with Val F1: 0.6785
# Epoch 50: Train Acc=75.6%, Val Acc=75.0%, F1=0.4286, AUC=0.7100
# Epoch 100: Train Acc=76.2%, Val Acc=75.0%, F1=0.4286, AUC=0.7500
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.4984
# Epoch 50: Train Acc=75.6%, Val Acc=75.0%, F1=0.4286, AUC=0.5233
# Epoch 100: Train Acc=75.9%, Val Acc=75.0%, F1=0.4286, AUC=0.5667
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.7253
# Epoch 50: Train Acc=75.6%, Val Acc=75.0%, F1=0.4286, AUC=0.8533
# Epoch 100: Train Acc=76.2%, Val Acc=75.0%, F1=0.4286, AUC=0.8200
#
# Average F1: 0.5220 ± 0.1065
# Average AUC: 0.6320 ± 0.1225

# %%
# %run finetune_noct.py \
    --modalities PFE \
    --data_file ../database/cfDNA/train/multimodal_data.npz \
    --epochs 100
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.6328
# New best model saved at epoch 5 with Val F1: 0.6661
# New best model saved at epoch 7 with Val F1: 0.7153
# Epoch 50: Train Acc=76.6%, Val Acc=68.3%, F1=0.6072, AUC=0.7290
# Epoch 100: Train Acc=78.3%, Val Acc=68.3%, F1=0.5839, AUC=0.7161
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 0.6273
# New best model saved at epoch 2 with Val F1: 0.6479
# Epoch 50: Train Acc=72.8%, Val Acc=73.2%, F1=0.6479, AUC=0.6355
# Epoch 100: Train Acc=76.4%, Val Acc=70.7%, F1=0.5729, AUC=0.6258
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.6894
# Epoch 50: Train Acc=75.3%, Val Acc=75.6%, F1=0.4306, AUC=0.9290
# Epoch 100: Train Acc=76.9%, Val Acc=75.6%, F1=0.4306, AUC=0.9032
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.5839
# New best model saved at epoch 3 with Val F1: 0.6232
# New best model saved at epoch 14 with Val F1: 0.6273
# Epoch 50: Train Acc=78.8%, Val Acc=65.9%, F1=0.5876, AUC=0.7806
# Epoch 100: Train Acc=76.4%, Val Acc=68.3%, F1=0.5839, AUC=0.7677
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.5119
# New best model saved at epoch 2 with Val F1: 0.5512
# New best model saved at epoch 6 with Val F1: 0.5693
# New best model saved at epoch 9 with Val F1: 0.5919
# Epoch 50: Train Acc=74.2%, Val Acc=75.6%, F1=0.5119, AUC=0.8871
# Epoch 100: Train Acc=76.1%, Val Acc=73.2%, F1=0.4972, AUC=0.8839
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.5429
# New best model saved at epoch 2 with Val F1: 0.6311
# New best model saved at epoch 14 with Val F1: 0.6537
# Epoch 50: Train Acc=74.2%, Val Acc=80.0%, F1=0.6537, AUC=0.6380
# Epoch 100: Train Acc=78.1%, Val Acc=72.5%, F1=0.5487, AUC=0.6308
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.7094
# Epoch 50: Train Acc=76.7%, Val Acc=70.0%, F1=0.4805, AUC=0.7367
# Epoch 100: Train Acc=77.5%, Val Acc=70.0%, F1=0.4805, AUC=0.7467
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.7656
# Epoch 50: Train Acc=74.5%, Val Acc=75.0%, F1=0.4286, AUC=0.8467
# Epoch 100: Train Acc=75.1%, Val Acc=72.5%, F1=0.4203, AUC=0.8367
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.6000
# Epoch 50: Train Acc=75.6%, Val Acc=60.0%, F1=0.4667, AUC=0.5033
# Epoch 100: Train Acc=76.2%, Val Acc=60.0%, F1=0.4667, AUC=0.5100
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 2 with Val F1: 0.7133
# Epoch 50: Train Acc=75.3%, Val Acc=72.5%, F1=0.6449, AUC=0.7700
# Epoch 100: Train Acc=75.3%, Val Acc=72.5%, F1=0.4203, AUC=0.7533
#
# Average F1: 0.6714 ± 0.0534
# Average AUC: 0.7758 ± 0.0905

# %%
# %run finetune_noct.py \
    --modalities NDR \
    --data_file ../database/cfDNA/train/multimodal_data.npz \
    --epochs 100
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 8 with Val F1: 0.5275
# New best model saved at epoch 21 with Val F1: 0.5886
# New best model saved at epoch 22 with Val F1: 0.6095
# New best model saved at epoch 29 with Val F1: 0.6800
# Epoch 50: Train Acc=91.2%, Val Acc=82.9%, F1=0.6800, AUC=0.8226
# New best model saved at epoch 58 with Val F1: 0.7416
# New best model saved at epoch 63 with Val F1: 0.7960
# New best model saved at epoch 64 with Val F1: 0.8145
# New best model saved at epoch 67 with Val F1: 0.8447
# New best model saved at epoch 77 with Val F1: 0.8576
# New best model saved at epoch 81 with Val F1: 0.8887
# New best model saved at epoch 94 with Val F1: 0.8972
# New best model saved at epoch 100 with Val F1: 0.9288
# Epoch 100: Train Acc=97.5%, Val Acc=95.1%, F1=0.9288, AUC=0.9871
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 7 with Val F1: 0.5275
# New best model saved at epoch 11 with Val F1: 0.6095
# New best model saved at epoch 12 with Val F1: 0.6800
# New best model saved at epoch 13 with Val F1: 0.7144
# Epoch 50: Train Acc=89.8%, Val Acc=78.0%, F1=0.6661, AUC=0.8355
# New best model saved at epoch 78 with Val F1: 0.7153
# Epoch 100: Train Acc=98.1%, Val Acc=75.6%, F1=0.6441, AUC=0.8742
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 6 with Val F1: 0.5275
# New best model saved at epoch 7 with Val F1: 0.5886
# New best model saved at epoch 9 with Val F1: 0.6555
# New best model saved at epoch 10 with Val F1: 0.7144
# New best model saved at epoch 13 with Val F1: 0.7670
# Epoch 50: Train Acc=91.5%, Val Acc=85.4%, F1=0.7670, AUC=0.9000
# New best model saved at epoch 58 with Val F1: 0.8145
# Epoch 100: Train Acc=97.8%, Val Acc=82.9%, F1=0.7602, AUC=0.9258
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 6 with Val F1: 0.6095
# New best model saved at epoch 13 with Val F1: 0.6800
# New best model saved at epoch 15 with Val F1: 0.7416
# New best model saved at epoch 28 with Val F1: 0.7670
# New best model saved at epoch 44 with Val F1: 0.8145
# Epoch 50: Train Acc=89.8%, Val Acc=87.8%, F1=0.8145, AUC=0.9355
# New best model saved at epoch 54 with Val F1: 0.8576
# Epoch 100: Train Acc=97.8%, Val Acc=90.2%, F1=0.8576, AUC=0.9323
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 7 with Val F1: 0.5275
# New best model saved at epoch 8 with Val F1: 0.6095
# New best model saved at epoch 9 with Val F1: 0.6800
# Epoch 50: Train Acc=89.8%, Val Acc=80.5%, F1=0.6555, AUC=0.8258
# New best model saved at epoch 57 with Val F1: 0.6894
# New best model saved at epoch 59 with Val F1: 0.7144
# Epoch 100: Train Acc=98.9%, Val Acc=80.5%, F1=0.6894, AUC=0.9355
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.4366
# New best model saved at epoch 11 with Val F1: 0.6078
# New best model saved at epoch 15 with Val F1: 0.6537
# Epoch 50: Train Acc=91.8%, Val Acc=80.0%, F1=0.6537, AUC=0.8602
# New best model saved at epoch 64 with Val F1: 0.7128
# New best model saved at epoch 65 with Val F1: 0.7656
# Epoch 100: Train Acc=97.8%, Val Acc=82.5%, F1=0.7386, AUC=0.8136
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.4203
# New best model saved at epoch 2 with Val F1: 0.4286
# New best model saved at epoch 7 with Val F1: 0.6078
# New best model saved at epoch 8 with Val F1: 0.6785
# New best model saved at epoch 9 with Val F1: 0.7403
# New best model saved at epoch 10 with Val F1: 0.7949
# New best model saved at epoch 12 with Val F1: 0.8438
# New best model saved at epoch 21 with Val F1: 0.8880
# Epoch 50: Train Acc=89.9%, Val Acc=92.5%, F1=0.8880, AUC=0.8833
# Epoch 100: Train Acc=98.4%, Val Acc=87.5%, F1=0.8133, AUC=0.8267
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 6 with Val F1: 0.5257
# New best model saved at epoch 7 with Val F1: 0.6078
# New best model saved at epoch 8 with Val F1: 0.6785
# New best model saved at epoch 9 with Val F1: 0.7403
# New best model saved at epoch 17 with Val F1: 0.7656
# New best model saved at epoch 22 with Val F1: 0.8133
# New best model saved at epoch 24 with Val F1: 0.8438
# Epoch 50: Train Acc=91.5%, Val Acc=90.0%, F1=0.8438, AUC=0.8100
# New best model saved at epoch 59 with Val F1: 0.8566
# Epoch 100: Train Acc=98.1%, Val Acc=87.5%, F1=0.8274, AUC=0.8533
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 10 with Val F1: 0.5098
# New best model saved at epoch 11 with Val F1: 0.6537
# New best model saved at epoch 14 with Val F1: 0.7128
# New best model saved at epoch 41 with Val F1: 0.7133
# New best model saved at epoch 44 with Val F1: 0.7386
# Epoch 50: Train Acc=90.7%, Val Acc=82.5%, F1=0.7386, AUC=0.8400
# New best model saved at epoch 89 with Val F1: 0.7656
# Epoch 100: Train Acc=98.4%, Val Acc=80.0%, F1=0.6875, AUC=0.8167
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.5257
# New best model saved at epoch 12 with Val F1: 0.6078
# New best model saved at epoch 13 with Val F1: 0.6785
# New best model saved at epoch 16 with Val F1: 0.7128
# New best model saved at epoch 49 with Val F1: 0.7656
# Epoch 50: Train Acc=90.4%, Val Acc=85.0%, F1=0.7656, AUC=0.9267
# Epoch 100: Train Acc=97.5%, Val Acc=85.0%, F1=0.7403, AUC=0.9433
#
# Average F1: 0.8072 ± 0.0697
# Average AUC: 0.8902 ± 0.0521

# %%
# %run finetune_noct.py \
    --modalities NDR2K \
    --data_file ../database/cfDNA/train/multimodal_data.npz \
    --epochs 100
# Out:
# Fold 1/10
# New best model saved at epoch 1 with Val F1: 0.5886
# New best model saved at epoch 11 with Val F1: 0.6117
# New best model saved at epoch 12 with Val F1: 0.6328
# New best model saved at epoch 46 with Val F1: 0.6555
# Epoch 50: Train Acc=86.5%, Val Acc=78.0%, F1=0.5886, AUC=0.6903
# New best model saved at epoch 65 with Val F1: 0.6800
# New best model saved at epoch 68 with Val F1: 0.7416
# New best model saved at epoch 83 with Val F1: 0.7960
# Epoch 100: Train Acc=98.4%, Val Acc=87.8%, F1=0.7960, AUC=0.9290
#
# Fold 2/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 3 with Val F1: 0.5886
# New best model saved at epoch 5 with Val F1: 0.6328
# New best model saved at epoch 27 with Val F1: 0.6555
# Epoch 50: Train Acc=86.0%, Val Acc=78.0%, F1=0.6328, AUC=0.5806
# Epoch 100: Train Acc=98.1%, Val Acc=78.0%, F1=0.6328, AUC=0.7935
#
# Fold 3/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 3 with Val F1: 0.5275
# New best model saved at epoch 4 with Val F1: 0.7144
# New best model saved at epoch 6 with Val F1: 0.7670
# New best model saved at epoch 7 with Val F1: 0.8145
# Epoch 50: Train Acc=85.2%, Val Acc=87.8%, F1=0.8145, AUC=0.8903
# New best model saved at epoch 81 with Val F1: 0.8576
# Epoch 100: Train Acc=98.1%, Val Acc=90.2%, F1=0.8576, AUC=0.9581
#
# Fold 4/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 4 with Val F1: 0.5119
# New best model saved at epoch 5 with Val F1: 0.7144
# New best model saved at epoch 7 with Val F1: 0.7670
# Epoch 50: Train Acc=86.5%, Val Acc=85.4%, F1=0.7416, AUC=0.9323
# New best model saved at epoch 67 with Val F1: 0.7960
# New best model saved at epoch 68 with Val F1: 0.8145
# New best model saved at epoch 71 with Val F1: 0.8447
# New best model saved at epoch 90 with Val F1: 0.8576
# Epoch 100: Train Acc=98.1%, Val Acc=90.2%, F1=0.8576, AUC=0.9548
#
# Fold 5/10
# New best model saved at epoch 1 with Val F1: 0.4306
# New best model saved at epoch 4 with Val F1: 0.6800
# New best model saved at epoch 6 with Val F1: 0.7416
# New best model saved at epoch 7 with Val F1: 0.7960
# Epoch 50: Train Acc=86.3%, Val Acc=80.5%, F1=0.6894, AUC=0.7387
# New best model saved at epoch 82 with Val F1: 0.8145
# Epoch 100: Train Acc=98.6%, Val Acc=87.8%, F1=0.8145, AUC=0.9097
#
# Fold 6/10
# New best model saved at epoch 1 with Val F1: 0.5429
# New best model saved at epoch 4 with Val F1: 0.6078
# New best model saved at epoch 7 with Val F1: 0.6785
# Epoch 50: Train Acc=86.8%, Val Acc=80.0%, F1=0.6537, AUC=0.8925
# New best model saved at epoch 65 with Val F1: 0.7403
# Epoch 100: Train Acc=98.1%, Val Acc=85.0%, F1=0.7403, AUC=0.9462
#
# Fold 7/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 3 with Val F1: 0.5257
# New best model saved at epoch 4 with Val F1: 0.6308
# New best model saved at epoch 6 with Val F1: 0.7584
# Epoch 50: Train Acc=86.0%, Val Acc=82.5%, F1=0.7584, AUC=0.8467
# New best model saved at epoch 55 with Val F1: 0.7849
# New best model saved at epoch 75 with Val F1: 0.8000
# New best model saved at epoch 81 with Val F1: 0.8386
# Epoch 100: Train Acc=96.4%, Val Acc=87.5%, F1=0.8386, AUC=0.9433
#
# Fold 8/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 4 with Val F1: 0.5867
# New best model saved at epoch 5 with Val F1: 0.7128
# New best model saved at epoch 6 with Val F1: 0.7656
# Epoch 50: Train Acc=87.1%, Val Acc=85.0%, F1=0.7656, AUC=0.8367
# New best model saved at epoch 77 with Val F1: 0.7849
# Epoch 100: Train Acc=98.1%, Val Acc=85.0%, F1=0.7849, AUC=0.9267
#
# Fold 9/10
# New best model saved at epoch 1 with Val F1: 0.4286
# New best model saved at epoch 5 with Val F1: 0.7403
# New best model saved at epoch 10 with Val F1: 0.7656
# Epoch 50: Train Acc=85.5%, Val Acc=85.0%, F1=0.7656, AUC=0.8133
# New best model saved at epoch 68 with Val F1: 0.8133
# Epoch 100: Train Acc=98.9%, Val Acc=87.5%, F1=0.8133, AUC=0.8300
#
# Fold 10/10
# New best model saved at epoch 1 with Val F1: 0.4667
# New best model saved at epoch 2 with Val F1: 0.5098
# New best model saved at epoch 6 with Val F1: 0.5671
# New best model saved at epoch 7 with Val F1: 0.6308
# New best model saved at epoch 35 with Val F1: 0.6875
# Epoch 50: Train Acc=87.4%, Val Acc=77.5%, F1=0.6308, AUC=0.7700
# New best model saved at epoch 62 with Val F1: 0.7386
# New best model saved at epoch 64 with Val F1: 0.7849
# New best model saved at epoch 67 with Val F1: 0.8274
# Epoch 100: Train Acc=97.3%, Val Acc=85.0%, F1=0.8000, AUC=0.9167
#
# Average F1: 0.7986 ± 0.0583
# Average AUC: 0.8730 ± 0.1137
