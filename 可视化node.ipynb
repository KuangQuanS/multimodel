# %%
import numpy as np
import matplotlib.pyplot as plt

npz_path = '/home/maweicheng/resgsca/database/3slice/64/nocancer/LIDC-IDRI-0003_slice066.npz'
data = np.load(npz_path)
print(data.keys())
image = data['data']

# 可视化图像
plt.imshow(image[:,:,1], cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()
# Out:
# KeysView(NpzFile '/home/maweicheng/resgsca/database/3slice/64/nocancer/LIDC-IDRI-0003_slice066.npz' with keys: data, mask)
